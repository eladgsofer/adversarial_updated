# %% [markdown]
# # Test on real world data

# %%
from helper import *
import torch
import torchvision
import torchvision.transforms as transforms
import os
from torch.optim import Adam


from torch import nn
import numpy as np

# %%
from torchvision.io import read_image, ImageReadMode

# %%
def BIM(model, x, L_gt, S_gt, eps=0.1, alpha=0.1, steps=3, **kwargs):
    """
    The BIM (Basic Iterative Method) adversarial attack is a technique used to generate adversarial examples usually
     for machine learning models. This function aims to attack ADMM/ISTA optimizers.
    :param model: ADMM/ISTA object, the target machine learning model to be attacked.
    :param x: torch vector x - x=Hs+w s.t w~N(0,0.001)
    :param s_gt: torch vector which represents s^*
    :param eps:   A small perturbation magnitude that controls the strength of the attack
    :param alpha: A step size parameter for adjusting the perturbation at each iteration
    :param steps: The number of iterations to perform the attack.
    :return: adversarial x signal and the pertubation which was applied.
    """
    x = x.clone()#.to(device)
    L_gt, S_gt = L_gt.clone(), S_gt.clone()

    original_x = x.data
    original_x.requires_grad = False

    adv_x = x.clone().detach()

    for step in range(steps):

        print("#################### BIM Step {0} distance ratio: {1} ####################".format(step, ((adv_x - original_x).norm() / original_x.norm()).item()))

        adv_x.requires_grad = True

        loss, l_hat, s_hat = model(adv_x, **kwargs)
        # model.zero_grad()

        # Calculate loss
        cost = torch.linalg.norm(original_x - l_hat - s_hat, 'fro')
        print("#################### COST: {0} ####################".format(cost.item()/torch.linalg.norm(original_x, 'fro')))

        # cost.backward(retain_graph=True)
        grad = torch.autograd.grad(cost, adv_x)[0]

        # Grad is calculated
        delta = alpha * grad.sign()

        # Stop following gradient changes
        adv_x = adv_x.clone().detach()

        adv_x = adv_x + delta

        # Clip the change between the adversarial images and the original images to an epsilon range
        eta = torch.clamp(adv_x - original_x, min=-eps, max=eps)

        adv_x = original_x + eta

    return adv_x, delta  # grad is the gradient (perturbation)

# %%
# !git clone https://github.com/Harry24k/adversarial-attacks-pytorch
# Out:
# Cloning into 'adversarial-attacks-pytorch'...
# remote: Enumerating objects: 3644, done.
# remote: Counting objects: 100% (698/698), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 3644 (delta 560), reused 529 (delta 529), pack-reused 2946 (from 1)
# Receiving objects: 100% (3644/3644), 51.75 MiB | 17.06 MiB/s, done.
# Resolving deltas: 100% (2305/2305), done.

# %%
# import sys
# sys.path.append("/content/adversarial-attacks-pytorch/torchattacks")
# import torchattacks

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import sys


device = "cpu"

def carlini_wagner(model, M_gt, c, steps, lr, **kwargs):

    M_gt = M_gt.clone().detach().to(device)


    # w = torch.zeros_like(images).detach() # Requires 2x times
    w = inverse_tanh_space(M_gt).detach()
    w.requires_grad = True

    MSELoss = nn.MSELoss(reduction="none")
    Flatten = nn.Flatten()

    optimizer = optim.Adam([w], lr=lr)

    for step in range(steps):
        # Get adversarial images
        adv_M = tanh_space(w)

        # Calculate loss
        current_L2 = MSELoss(Flatten(adv_M), Flatten(M_gt)).sum(dim=1)
        L2_loss = current_L2.sum()

        model_loss, L0_adv, S0_adv = AccAltProj(adv_M, **kwargs)
        outputs = L0_adv+S0_adv

        f_loss = f(outputs, M_gt).sum()

        cost = L2_loss + c * f_loss

        optimizer.zero_grad()
        cost.backward()
        optimizer.step()
        print("### COST ",model_loss[-1].item(), L2_loss.item(),  c*f_loss.item(), "###")


    return adv_M, L0_adv, S0_adv

def tanh_space(x):
    return 1 / 2 * (torch.tanh(x) + 1)

def inverse_tanh_space(x):
    # torch.atanh is only for torch >= 1.7.0
    # atanh is defined in the range -1 to 1
    return atanh(torch.clamp(x * 2 - 1, min=-1, max=1))

def atanh(x):
    return 0.5 * torch.log((1 + x) / (1 - x))

# f-function in the paper
def f(outputs, labels):
  # current_fro = torch.linalg.norm(original_x - l_hat - s_hat, 'fro')
    # loss = nn.MSELoss
    # if outputs.shape!=labels.shape:
    #     cost = loss(outputs, labels.T)
    # else:
    cost = torch.linalg.norm(outputs - labels,'fro')

    return -1*cost

# %%
# Before this one, drag the zip file to the current directory
# !unzip data_pngs.zip -d data_pngs
# Out:
# Archive:  data_pngs.zip
#    creating: data_pngs/data_pngs/
#    creating: data_pngs/data_pngs/subject01/
#   inflating: data_pngs/data_pngs/subject01/subject01_centerlight.png
#   inflating: data_pngs/data_pngs/subject01/subject01_glasses.png
#   inflating: data_pngs/data_pngs/subject01/subject01_happy.png
#   inflating: data_pngs/data_pngs/subject01/subject01_leftlight.png
#   inflating: data_pngs/data_pngs/subject01/subject01_noglasses.png
#   inflating: data_pngs/data_pngs/subject01/subject01_normal.png
#   inflating: data_pngs/data_pngs/subject01/subject01_rightlight.png
#   inflating: data_pngs/data_pngs/subject01/subject01_sad.png
#   inflating: data_pngs/data_pngs/subject01/subject01_sleepy.png
#   inflating: data_pngs/data_pngs/subject01/subject01_surprised.png
#   inflating: data_pngs/data_pngs/subject01/subject01_wink.png
#    creating: data_pngs/data_pngs/subject02/
#   inflating: data_pngs/data_pngs/subject02/subject02_centerlight.png
#   inflating: data_pngs/data_pngs/subject02/subject02_glasses.png
#   inflating: data_pngs/data_pngs/subject02/subject02_happy.png
#   inflating: data_pngs/data_pngs/subject02/subject02_leftlight.png
#   inflating: data_pngs/data_pngs/subject02/subject02_noglasses.png
#   inflating: data_pngs/data_pngs/subject02/subject02_normal.png
#   inflating: data_pngs/data_pngs/subject02/subject02_rightlight.png
#   inflating: data_pngs/data_pngs/subject02/subject02_sad.png
#   inflating: data_pngs/data_pngs/subject02/subject02_sleepy.png
#   inflating: data_pngs/data_pngs/subject02/subject02_surprised.png
#   inflating: data_pngs/data_pngs/subject02/subject02_wink.png
#    creating: data_pngs/data_pngs/subject03/
#   inflating: data_pngs/data_pngs/subject03/subject03_centerlight.png
#   inflating: data_pngs/data_pngs/subject03/subject03_glasses.png
#   inflating: data_pngs/data_pngs/subject03/subject03_happy.png
#   inflating: data_pngs/data_pngs/subject03/subject03_leftlight.png
#   inflating: data_pngs/data_pngs/subject03/subject03_noglasses.png
#   inflating: data_pngs/data_pngs/subject03/subject03_normal.png
#   inflating: data_pngs/data_pngs/subject03/subject03_rightlight.png
#   inflating: data_pngs/data_pngs/subject03/subject03_sad.png
#   inflating: data_pngs/data_pngs/subject03/subject03_sleepy.png
#   inflating: data_pngs/data_pngs/subject03/subject03_surprised.png
#   inflating: data_pngs/data_pngs/subject03/subject03_wink.png
#    creating: data_pngs/data_pngs/subject04/
#   inflating: data_pngs/data_pngs/subject04/subject04_centerlight.png
#   inflating: data_pngs/data_pngs/subject04/subject04_glasses.png
#   inflating: data_pngs/data_pngs/subject04/subject04_happy.png
#   inflating: data_pngs/data_pngs/subject04/subject04_leftlight.png
#   inflating: data_pngs/data_pngs/subject04/subject04_noglasses.png
#   inflating: data_pngs/data_pngs/subject04/subject04_normal.png
#   inflating: data_pngs/data_pngs/subject04/subject04_rightlight.png
#   inflating: data_pngs/data_pngs/subject04/subject04_sad.png
#   inflating: data_pngs/data_pngs/subject04/subject04_sleepy.png
#   inflating: data_pngs/data_pngs/subject04/subject04_surprised.png
#   inflating: data_pngs/data_pngs/subject04/subject04_wink.png
#    creating: data_pngs/data_pngs/subject05/
#   inflating: data_pngs/data_pngs/subject05/subject05_centerlight.png
#   inflating: data_pngs/data_pngs/subject05/subject05_glasses.png
#   inflating: data_pngs/data_pngs/subject05/subject05_happy.png
#   inflating: data_pngs/data_pngs/subject05/subject05_leftlight.png
#   inflating: data_pngs/data_pngs/subject05/subject05_noglasses.png
#   inflating: data_pngs/data_pngs/subject05/subject05_normal.png
#   inflating: data_pngs/data_pngs/subject05/subject05_rightlight.png
#   inflating: data_pngs/data_pngs/subject05/subject05_sad.png
#   inflating: data_pngs/data_pngs/subject05/subject05_sleepy.png
#   inflating: data_pngs/data_pngs/subject05/subject05_surprised.png
#   inflating: data_pngs/data_pngs/subject05/subject05_wink.png
#    creating: data_pngs/data_pngs/subject06/
#   inflating: data_pngs/data_pngs/subject06/subject06_centerlight.png
#   inflating: data_pngs/data_pngs/subject06/subject06_glasses.png
#   inflating: data_pngs/data_pngs/subject06/subject06_happy.png
#   inflating: data_pngs/data_pngs/subject06/subject06_leftlight.png
#   inflating: data_pngs/data_pngs/subject06/subject06_noglasses.png
#   inflating: data_pngs/data_pngs/subject06/subject06_normal.png
#   inflating: data_pngs/data_pngs/subject06/subject06_rightlight.png
#   inflating: data_pngs/data_pngs/subject06/subject06_sad.png
#   inflating: data_pngs/data_pngs/subject06/subject06_sleepy.png
#   inflating: data_pngs/data_pngs/subject06/subject06_surprised.png
#   inflating: data_pngs/data_pngs/subject06/subject06_wink.png
#    creating: data_pngs/data_pngs/subject07/
#   inflating: data_pngs/data_pngs/subject07/subject07_centerlight.png
#   inflating: data_pngs/data_pngs/subject07/subject07_glasses.png
#   inflating: data_pngs/data_pngs/subject07/subject07_happy.png
#   inflating: data_pngs/data_pngs/subject07/subject07_leftlight.png
#   inflating: data_pngs/data_pngs/subject07/subject07_noglasses.png
#   inflating: data_pngs/data_pngs/subject07/subject07_normal.png
#   inflating: data_pngs/data_pngs/subject07/subject07_rightlight.png
#   inflating: data_pngs/data_pngs/subject07/subject07_sad.png
#   inflating: data_pngs/data_pngs/subject07/subject07_sleepy.png
#   inflating: data_pngs/data_pngs/subject07/subject07_surprised.png
#   inflating: data_pngs/data_pngs/subject07/subject07_wink.png
#    creating: data_pngs/data_pngs/subject08/
#   inflating: data_pngs/data_pngs/subject08/subject08_centerlight.png
#   inflating: data_pngs/data_pngs/subject08/subject08_glasses.png
#   inflating: data_pngs/data_pngs/subject08/subject08_happy.png
#   inflating: data_pngs/data_pngs/subject08/subject08_leftlight.png
#   inflating: data_pngs/data_pngs/subject08/subject08_noglasses.png
#   inflating: data_pngs/data_pngs/subject08/subject08_normal.png
#   inflating: data_pngs/data_pngs/subject08/subject08_rightlight.png
#   inflating: data_pngs/data_pngs/subject08/subject08_sad.png
#   inflating: data_pngs/data_pngs/subject08/subject08_sleepy.png
#   inflating: data_pngs/data_pngs/subject08/subject08_surprised.png
#   inflating: data_pngs/data_pngs/subject08/subject08_wink.png
#    creating: data_pngs/data_pngs/subject09/
#   inflating: data_pngs/data_pngs/subject09/subject09_centerlight.png
#   inflating: data_pngs/data_pngs/subject09/subject09_glasses.png
#   inflating: data_pngs/data_pngs/subject09/subject09_happy.png
#   inflating: data_pngs/data_pngs/subject09/subject09_leftlight.png
#   inflating: data_pngs/data_pngs/subject09/subject09_noglasses.png
#   inflating: data_pngs/data_pngs/subject09/subject09_normal.png
#   inflating: data_pngs/data_pngs/subject09/subject09_rightlight.png
#   inflating: data_pngs/data_pngs/subject09/subject09_sad.png
#   inflating: data_pngs/data_pngs/subject09/subject09_sleepy.png
#   inflating: data_pngs/data_pngs/subject09/subject09_surprised.png
#   inflating: data_pngs/data_pngs/subject09/subject09_wink.png
#    creating: data_pngs/data_pngs/subject10/
#   inflating: data_pngs/data_pngs/subject10/subject10_centerlight.png
#   inflating: data_pngs/data_pngs/subject10/subject10_glasses.png
#   inflating: data_pngs/data_pngs/subject10/subject10_happy.png
#   inflating: data_pngs/data_pngs/subject10/subject10_leftlight.png
#   inflating: data_pngs/data_pngs/subject10/subject10_noglasses.png
#   inflating: data_pngs/data_pngs/subject10/subject10_normal.png
#   inflating: data_pngs/data_pngs/subject10/subject10_rightlight.png
#   inflating: data_pngs/data_pngs/subject10/subject10_sad.png
#   inflating: data_pngs/data_pngs/subject10/subject10_sleepy.png
#   inflating: data_pngs/data_pngs/subject10/subject10_surprised.png
#   inflating: data_pngs/data_pngs/subject10/subject10_wink.png
#    creating: data_pngs/data_pngs/subject11/
#   inflating: data_pngs/data_pngs/subject11/subject11_centerlight.png
#   inflating: data_pngs/data_pngs/subject11/subject11_glasses.png
#   inflating: data_pngs/data_pngs/subject11/subject11_happy.png
#   inflating: data_pngs/data_pngs/subject11/subject11_leftlight.png
#   inflating: data_pngs/data_pngs/subject11/subject11_noglasses.png
#   inflating: data_pngs/data_pngs/subject11/subject11_normal.png
#   inflating: data_pngs/data_pngs/subject11/subject11_rightlight.png
#   inflating: data_pngs/data_pngs/subject11/subject11_sad.png
#   inflating: data_pngs/data_pngs/subject11/subject11_sleepy.png
#   inflating: data_pngs/data_pngs/subject11/subject11_surprised.png
#   inflating: data_pngs/data_pngs/subject11/subject11_wink.png
#    creating: data_pngs/data_pngs/subject12/
#   inflating: data_pngs/data_pngs/subject12/subject12_centerlight.png
#   inflating: data_pngs/data_pngs/subject12/subject12_glasses.png
#   inflating: data_pngs/data_pngs/subject12/subject12_happy.png
#   inflating: data_pngs/data_pngs/subject12/subject12_leftlight.png
#   inflating: data_pngs/data_pngs/subject12/subject12_noglasses.png
#   inflating: data_pngs/data_pngs/subject12/subject12_normal.png
#   inflating: data_pngs/data_pngs/subject12/subject12_rightlight.png
#   inflating: data_pngs/data_pngs/subject12/subject12_sad.png
#   inflating: data_pngs/data_pngs/subject12/subject12_sleepy.png
#   inflating: data_pngs/data_pngs/subject12/subject12_surprised.png
#   inflating: data_pngs/data_pngs/subject12/subject12_wink.png
#    creating: data_pngs/data_pngs/subject13/
#   inflating: data_pngs/data_pngs/subject13/subject13_centerlight.png
#   inflating: data_pngs/data_pngs/subject13/subject13_glasses.png
#   inflating: data_pngs/data_pngs/subject13/subject13_happy.png
#   inflating: data_pngs/data_pngs/subject13/subject13_leftlight.png
#   inflating: data_pngs/data_pngs/subject13/subject13_noglasses.png
#   inflating: data_pngs/data_pngs/subject13/subject13_normal.png
#   inflating: data_pngs/data_pngs/subject13/subject13_rightlight.png
#   inflating: data_pngs/data_pngs/subject13/subject13_sad.png
#   inflating: data_pngs/data_pngs/subject13/subject13_sleepy.png
#   inflating: data_pngs/data_pngs/subject13/subject13_surprised.png
#   inflating: data_pngs/data_pngs/subject13/subject13_wink.png
#    creating: data_pngs/data_pngs/subject14/
#   inflating: data_pngs/data_pngs/subject14/subject14_centerlight.png
#   inflating: data_pngs/data_pngs/subject14/subject14_glasses.png
#   inflating: data_pngs/data_pngs/subject14/subject14_happy.png
#   inflating: data_pngs/data_pngs/subject14/subject14_leftlight.png
#   inflating: data_pngs/data_pngs/subject14/subject14_noglasses.png
#   inflating: data_pngs/data_pngs/subject14/subject14_normal.png
#   inflating: data_pngs/data_pngs/subject14/subject14_rightlight.png
#   inflating: data_pngs/data_pngs/subject14/subject14_sad.png
#   inflating: data_pngs/data_pngs/subject14/subject14_sleepy.png
#   inflating: data_pngs/data_pngs/subject14/subject14_surprised.png
#   inflating: data_pngs/data_pngs/subject14/subject14_wink.png
#    creating: data_pngs/data_pngs/subject15/
#   inflating: data_pngs/data_pngs/subject15/subject15_centerlight.png
#   inflating: data_pngs/data_pngs/subject15/subject15_glasses.png
#   inflating: data_pngs/data_pngs/subject15/subject15_happy.png
#   inflating: data_pngs/data_pngs/subject15/subject15_leftlight.png
#   inflating: data_pngs/data_pngs/subject15/subject15_noglasses.png
#   inflating: data_pngs/data_pngs/subject15/subject15_normal.png
#   inflating: data_pngs/data_pngs/subject15/subject15_rightlight.png
#   inflating: data_pngs/data_pngs/subject15/subject15_sad.png
#   inflating: data_pngs/data_pngs/subject15/subject15_sleepy.png
#   inflating: data_pngs/data_pngs/subject15/subject15_surprised.png
#   inflating: data_pngs/data_pngs/subject15/subject15_wink.png

# %%
dir = "/content/data_pngs/data_pngs"
subjects = {}
for subject in os.listdir(dir):
    for pic in os.listdir(os.path.join(dir, subject)):
        f = os.path.join(dir, subject, pic)
        img = read_image(f, ImageReadMode.GRAY)
        img = torchvision.transforms.ConvertImageDtype(torch.float64)(img)
        img = torch.flatten(img.squeeze().T)
        if subjects.get(subject) == None:
            subjects[subject] = img
        else:
            subjects[subject] = torch.column_stack((subjects[subject], img))

# %% [markdown]
# ## New functions

# %%
def thres(inputs, t, hard=True, old=True):
    if not hard:
        out = torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))
    else:
        if old:
            out = inputs * (torch.abs(inputs) > t)
        else:
            # out = torch.sign(inputs) * torch.max(\
            #                                     torch.abs(inputs) - torch.nan_to_num(torch.div(torch.pow(t, 6), torch.pow(torch.abs(inputs), 5))) \
            #                                     , torch.zeros(inputs.shape))
            # out = torch.sign(inputs) * torch.max(torch.abs(inputs) \
            #                                     - torch.div(t, torch.exp(3 * torch.div(torch.abs(inputs) - t, t))) \
            #                                     , torch.zeros(inputs.shape))
            # out = inputs * torch.max(1 - torch.div(torch.pow(t, 2), torch.pow(inputs, 2)), torch.zeros(inputs.shape))
            # out = torch.div(1,  1 + torch.exp(-100 * (torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape))))) \
            #         + torch.sign(inputs) * torch.max(torch.abs(inputs)- t, torch.zeros(inputs.shape)) \
            #         - t
            # mu = 1.0005 * t
            # out = inputs * (torch.abs(inputs) >= mu) \
            #         + torch.sign(inputs) * (mu/(mu-t))*(torch.abs(inputs) - t) * (mu > torch.abs(inputs)) * (torch.abs(inputs) >= t)
            gamma, beta = 0.95, 1
            out = inputs * (torch.abs(inputs) > torch.sqrt(gamma * beta * t**2)) * (beta <= gamma) \
                    + torch.sign(inputs) * torch.min(beta/(beta - gamma) * torch.max(torch.abs(inputs) - (t * gamma), torch.zeros(inputs.shape)), torch.abs(inputs)) * (beta > gamma)
    return out

# %%
## ======================== Learned AccAltProj model ========================
## recover low-rank matrix L from M = L + S

class InitStage(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, M0, r):
        m, n = M0.shape
        norm_of_M0 = torch.linalg.norm(M0)
        beta = 1/(2 * np.power(m * n, 1/4))
        beta_init = 4 * beta
        zeta = beta_init * torch.linalg.norm(M0, 2)
        S = thres(M0, zeta, hard=True, old=False)
        U, Sigma, V = torch.linalg.svd(M0 - S, full_matrices=False)
        U, Sigma, V = U[:,:r], Sigma[:r], V.t()[:, :r]
        L = U @ torch.diag(Sigma) @ V.t()
        zeta = beta * Sigma[0]
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V, beta, norm_of_M0

class ProjStage(nn.Module):
    def __init__(self, gamma, lay):
        super().__init__()
        self.gamma = gamma
        self.lay = lay
    def forward(self, M0, S, U, V, r, beta):
        ## Update L
        Z = M0 - S
        Q1, R1 = torch.linalg.qr(Z.t() @ U - V @ ((Z @ V).t() @ U)) ## reduced QR
        Q2, R2 = torch.linalg.qr(Z @ V - U @ (U.t() @ Z @ V)) ## reduced QR
        A = torch.cat((torch.cat((U.t() @ Z @ V, R1.t()), 1),
                        torch.cat((R2, torch.zeros(R2.shape)), 1)), 0) ## A is 2r x 2r matrix
        Um, Sm, Vm = torch.linalg.svd(A, full_matrices=False)
        U = torch.cat((U, Q2), 1) @ Um[:,:r]
        V = torch.cat((V, Q1), 1) @ Vm.t()[:,:r]
        L = U @ torch.diag(Sm[:r]) @ V.t()
        ## Update S
        zeta = beta * (Sm[r] + torch.pow(self.gamma, self.lay) * Sm[0])
        S = M0 - L
        S = thres(S, zeta, hard=True, old=False)
        return S, L, U, V

class LearnedAAP(nn.Module):
    def __init__(self, max_iter, d1, d2):
        super().__init__()
        self.max_iter = max_iter
        self.gamma = nn.Parameter(torch.tensor(0.7))
        #self.gamma = torch.tensor(0.7)
        self.beta = nn.Parameter(torch.tensor(1/(2 * np.power(d1 * d2, 1/4))))

        ## Stack layers
        self.layer = [InitStage()]
        for t in range(max_iter):
            #self.layer.append(ProjStage(gamma = nn.Parameter(torch.pow(self.gamma.clone().detach(), t + 1).requires_grad_(True))))
            #self.layer.append(ProjStage(gamma = nn.Parameter(self.gamma.clone().detach().requires_grad_(True))))
            self.layer.append(ProjStage(self.gamma, t+1))
        self.layers = nn.Sequential(*self.layer)
        ## Track loss
        self.err = np.zeros(max_iter + 1)

    def forward(self, M0, r):
        lay_init = self.layers[0]
        S, L, U, V, beta, norm_of_M0 = lay_init(M0, r)
        for t in range(1, self.max_iter + 1):
            lay = self.layers[t]
            S, L, U, V = lay(M0, S, U, V, r, self.beta)
            self.err[t] = torch.linalg.norm(M0 - L - S)/ norm_of_M0
        return L, S

# %%
def train_nn(net, r, lr, weight_decay, nepochs, dataset):
    torch.autograd.set_detect_anomaly(False)
    params_bftrain = [x.clone().detach().numpy() for x in list(net.parameters())]
    optimizer = Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
    l0_norm_of_S_Shat = []
    for epoch in range(nepochs):
        for i in range(len(dataset)):
            L0, S0, M0 = dataset[i]
            optimizer.zero_grad()
            L_hat, S_hat = net(M0, r)
            print(net.err[-1])
            loss = torch.pow(torch.linalg.norm(L0 - L_hat), 2)/ torch.pow(torch.linalg.norm(L0), 2) \
                    + torch.pow(torch.linalg.norm(S0 - S_hat), 2)/ torch.pow(torch.linalg.norm(S0), 2) \
                    #+ torch.pow(torch.linalg.norm(M0 - L_hat - S_hat), 2)
            # loss = torch.linalg.norm(L0 - L_hat)/ torch.linalg.norm(L0) \
            #         + torch.linalg.norm(S0 - S_hat)/ torch.linalg.norm(S0)
            loss.backward()
            optimizer.step()
            l0_norm_of_S_Shat.append(torch.count_nonzero(S0 - S_hat))
            print(list(net.parameters()))
            print(net.gamma.grad, net.beta.grad)
            print('Epoch ' + str(epoch+1) +'/' + str(nepochs) +' at cost=' + str(loss.item()))
    print('Finished Training')
    params_aftrain = [x.clone().detach().numpy() for x in list(net.parameters())]
    return net, params_bftrain, params_aftrain, l0_norm_of_S_Shat

# %%
def get_net_outputs(net_trained, net_bftrain, r, dataset):
    out_bftrain = []
    out_hat = []
    for i in range(len(dataset)):
        M_true = dataset[i]
        L_bftrain, S_bftrain = net_bftrain(M_true, r)
        print(net_bftrain.err[-1])
        out_bftrain.append((L_bftrain.detach().numpy(), S_bftrain.detach().numpy()))
        L_hat, S_hat = net_trained(M_true, r)
        print(net_trained.err[-1])
        out_hat.append((L_hat.detach().numpy(), S_hat.detach().numpy()))
    out_bftrain = np.asarray(out_bftrain)
    out_hat = np.asarray(out_hat)
    return out_bftrain, out_hat

# %%
def plot_true_vs_est_matrices(L_hat, L_adv, L_true, S_hat, S_adv, S_true):
    combined = np.concatenate((L_hat, L_adv, L_true, S_hat, S_adv, S_true))
    #fig, [ax1, ax2] = plt.subplots(1,2)
    plt.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    plt.show()
    plt.imshow(L_adv, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax1.set_title("L_hat")
    #plt.colorbar(im1, ax=ax1)
    plt.show()
    plt.imshow(L_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax2.set_title("L_true")
    #plt.colorbar(im2, ax=ax2)
    plt.show()
    #fig, [ax3, ax4] = plt.subplots(1,2)
    plt.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    plt.show()

    plt.imshow(S_adv, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax3.set_title("S_hat")
    #plt.colorbar(im3, ax=ax3)
    plt.show()
    plt.imshow(S_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax4.set_title("S_true")
    #plt.colorbar(im4, ax=ax4)
    plt.show()

def plot_true_vs_est_matrices_original(L_hat, L_true, S_hat, S_true):
    combined = np.concatenate((L_hat, L_true, S_hat, S_true))
    #fig, [ax1, ax2] = plt.subplots(1,2)
    plt.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax1.set_title("L_hat")
    #plt.colorbar(im1, ax=ax1)
    plt.show()
    plt.imshow(L_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax2.set_title("L_true")
    #plt.colorbar(im2, ax=ax2)
    plt.show()
    #fig, [ax3, ax4] = plt.subplots(1,2)
    plt.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax3.set_title("S_hat")
    #plt.colorbar(im3, ax=ax3)
    plt.show()
    plt.imshow(S_true, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    #ax4.set_title("S_true")
    #plt.colorbar(im4, ax=ax4)
    plt.show()

# %%
def resample(m, n, siz_row, siz_col):
    rows = np.random.randint(0, m, size=[1, siz_row])
    cols = np.random.randint(0, n, size=[1, siz_col])
    return [np.unique(rows), np.unique(cols)]

def AccAltProj(M0, r, tol, gamma, max_iter):
    m, n = M0.shape

    print(f"N: {n} M: {m}")


    norm_of_M0 = torch.linalg.norm(M0)
    ## Keep track of loss
    loss = []
    ## Initialization
    beta = 1/(2 * np.power(m * n, 1/4))
    beta_init = 4 * beta
    zeta = beta_init * torch.linalg.norm(M0, 2)
    S = thres(M0, zeta)#, False)
    U, Sigma, V = torch.linalg.svd(M0 - S, full_matrices=False)
    ## NOTE: torch.linalg.svd(M) returns U, S, V such that M=USV not USV.T
    U, Sigma, V = U[:,:r], Sigma[:r], V.t()[:, :r]
    L = U @ torch.diag(Sigma) @ V.t()
    zeta = beta * Sigma[0]
    S = thres(M0 - L, zeta)#, False)
    ## Initial loss
    err = torch.linalg.norm(M0 - L - S)/ norm_of_M0
    loss.append(err)
    for t in range(max_iter):
        ## Update L
        Z = M0 - S
        Q1, R1 = torch.linalg.qr(Z.t() @ U - V @ ((Z @ V).t() @ U)) ## reduced QR
        Q2, R2 = torch.linalg.qr(Z @ V - U @ (U.t() @ Z @ V)) ## reduced QR
        A = torch.cat((torch.cat((U.t() @ Z @ V, R1.t()), 1),
                        torch.cat((R2, torch.zeros(R2.shape)), 1)), 0) ## A is 2r x 2r matrix
        Um, Sigma, Vm = torch.linalg.svd(A, full_matrices=False)
        U = torch.cat((U, Q2), 1) @ Um[:,:r]
        V = torch.cat((V, Q1), 1) @ Vm.t()[:,:r]
        L = U @ torch.diag(Sigma[:r]) @ V.t()
        ## Update S
        zeta = beta * (Sigma[r] + torch.pow(gamma, t + 1) * Sigma[0])
        S = thres(M0 - L, zeta)#, False)
        ## Compute error
        err = torch.linalg.norm(M0 - L - S)/ norm_of_M0
        loss.append(err)
        if err < tol:
            return loss, L, S
    return loss, L, S



## returns: loss, L, S
def IRCUR(M0, r, tol, gamma, con, max_iter):
    m, n = M0.shape
    norm_of_M0 = torch.linalg.norm(M0)
    ## Keep track of loss
    loss = []
    ## Initialization
    siz_row, siz_col = np.ceil(con * r * np.log(m)).astype(np.int64), np.ceil(con * r * np.log(n)).astype(np.int64)
    zeta = torch.max(torch.abs(M0))
    C, pinv_U, R = torch.zeros(M0.shape), torch.zeros([M0.shape[1], M0.shape[0]]), torch.zeros(M0.shape)
    for t in range(max_iter):
        ## resample rows and columns
        rows, cols = resample(m, n, siz_row, siz_col)
        M0_rows = M0[rows, :]
        M0_cols = M0[:, cols]
        norm_of_M0 = torch.linalg.norm(M0_rows) + torch.linalg.norm(M0_cols)
        ## compute submatrices of L from previous iteration
        L_rows = C[rows, :] @ pinv_U @ R
        L_cols = C @ pinv_U @ R[:, cols]
        ## update S using submatrices of L
        S_rows = thres(M0_rows - L_rows, zeta)
        S_cols = thres(M0_cols - L_cols, zeta)
        ## update L
        C = M0_cols - S_cols
        R = M0_rows - S_rows
        MU = C[rows, :]
        U,Sigma,Vh = torch.linalg.svd(MU, full_matrices=False)
        ## calculate Moore-Penrose inverse of Sigma
        pinv_U = Vh.t()[:,:r] @ torch.diag(1./Sigma[:r]) @ U[:, :r].t()
        ## update zeta
        zeta = gamma * zeta
        ## update loss
        err = (torch.linalg.norm(M0_rows - L_rows - S_rows) + torch.linalg.norm(M0_cols - L_cols - S_cols))/ norm_of_M0
        loss.append(err)
        if err < tol:
            L = C @ pinv_U @ R
            S = thres(M0 - L, zeta)
            return loss, L, S
    L = C @ pinv_U @ R
    S = thres(M0 - L, zeta)
    return loss, L, S

# %% [markdown]
# ## Training

# %%
r = 1
max_iter = 50

# %%
print("original beta =", 1/(2 * np.power(243 * 320 * 11, 1/4)))
# Out:
# original beta = 0.01644117189829903

# %%
train = [subjects[x] for x in ['subject01', 'subject02', 'subject03', 'subject04', 'subject05', 'subject06', 'subject07']]
test = [subjects[x] for x in ['subject08', 'subject09', 'subject10', 'subject11', 'subject12', 'subject13', 'subject14', 'subject15']]

# %%
train_est = []
for i, M_true in enumerate(train):
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    train_est.append((L0, S0, M_true))
    print(loss[-1])
# Out:
# tensor(6.7150e-07, dtype=torch.float64)
# tensor(9.6613e-07, dtype=torch.float64)
# tensor(5.9604e-07, dtype=torch.float64)
# tensor(7.9321e-07, dtype=torch.float64)
# tensor(7.6721e-07, dtype=torch.float64)
# tensor(6.9194e-07, dtype=torch.float64)
# tensor(7.2509e-07, dtype=torch.float64)

# %%
net, params_bftrain, params_aftrain, l0_norm_of_S_Shat = train_nn(LearnedAAP(max_iter, 243 * 320, 11), r \
                                                                    , lr=2e-04, weight_decay=0 \
                                                                    , nepochs=8, dataset=train_est)
# Out:
# 9.526961563913226e-09
# [Parameter containing:
# tensor(0.6998, requires_grad=True), Parameter containing:
# tensor(0.0162, dtype=torch.float64, requires_grad=True)]
# tensor(1.0445) tensor(4.7193, dtype=torch.float64)
# Epoch 1/8 at cost=0.03433624843410157
# 1.7590502687541185e-08
# [Parameter containing:
# tensor(0.6997, requires_grad=True), Parameter containing:
# tensor(0.0161, dtype=torch.float64, requires_grad=True)]
# tensor(0.0965) tensor(0.1852, dtype=torch.float64)
# Epoch 1/8 at cost=0.026872306984300837
# 1.513187176634218e-08
# [Parameter containing:
# tensor(0.6997, requires_grad=True), Parameter containing:
# tensor(0.0161, dtype=torch.float64, requires_grad=True)]
# tensor(-1.6306) tensor(-5.4064, dtype=torch.float64)
# Epoch 1/8 at cost=0.07764313104099194
# 1.9958992538641398e-08
# [Parameter containing:
# tensor(0.6997, requires_grad=True), Parameter containing:
# tensor(0.0161, dtype=torch.float64, requires_grad=True)]
# tensor(0.4328) tensor(0.8175, dtype=torch.float64)
# Epoch 1/8 at cost=0.06525007935076041
# 1.3630160135246497e-08
# [Parameter containing:
# tensor(0.6997, requires_grad=True), Parameter containing:
# tensor(0.0161, dtype=torch.float64, requires_grad=True)]
# tensor(0.0013) tensor(-0.0163, dtype=torch.float64)
# Epoch 1/8 at cost=0.020676391071953154
# 2.03032479533514e-08
# [Parameter containing:
# tensor(0.6996, requires_grad=True), Parameter containing:
# tensor(0.0160, dtype=torch.float64, requires_grad=True)]
# tensor(18.6182) tensor(89.5938, dtype=torch.float64)
# Epoch 1/8 at cost=0.38127117130265703
# 8.37919927198325e-09
# [Parameter containing:
# tensor(0.6995, requires_grad=True), Parameter containing:
# tensor(0.0159, dtype=torch.float64, requires_grad=True)]
# tensor(0.8293) tensor(3.6469, dtype=torch.float64)
# Epoch 1/8 at cost=0.48591083920009914
# 9.43175130038693e-09
# [Parameter containing:
# tensor(0.6994, requires_grad=True), Parameter containing:
# tensor(0.0159, dtype=torch.float64, requires_grad=True)]
# tensor(-0.2574) tensor(-1.6670, dtype=torch.float64)
# Epoch 2/8 at cost=0.03365333878304411
# 1.594253721452475e-08
# [Parameter containing:
# tensor(0.6994, requires_grad=True), Parameter containing:
# tensor(0.0158, dtype=torch.float64, requires_grad=True)]
# tensor(0.5548) tensor(1.9448, dtype=torch.float64)
# Epoch 2/8 at cost=0.0271691536519943
# 1.5254701894821283e-08
# [Parameter containing:
# tensor(0.6993, requires_grad=True), Parameter containing:
# tensor(0.0157, dtype=torch.float64, requires_grad=True)]
# tensor(16.9148) tensor(91.8756, dtype=torch.float64)
# Epoch 2/8 at cost=0.06179787026317284
# 1.7989500091125572e-08
# [Parameter containing:
# tensor(0.6991, requires_grad=True), Parameter containing:
# tensor(0.0156, dtype=torch.float64, requires_grad=True)]
# tensor(0.7859) tensor(2.9496, dtype=torch.float64)
# Epoch 2/8 at cost=0.06529907421892983
# 1.404193307799329e-08
# [Parameter containing:
# tensor(0.6990, requires_grad=True), Parameter containing:
# tensor(0.0155, dtype=torch.float64, requires_grad=True)]
# tensor(0.0571) tensor(0.1808, dtype=torch.float64)
# Epoch 2/8 at cost=0.020773862816485186
# 1.6109837077484007e-08
# [Parameter containing:
# tensor(0.6990, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(0.3565) tensor(-4.5680, dtype=torch.float64)
# Epoch 2/8 at cost=0.3897808871030041
# 8.686272776498646e-09
# [Parameter containing:
# tensor(0.6989, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(-0.2607) tensor(-1.6884, dtype=torch.float64)
# Epoch 2/8 at cost=0.48872382204966314
# 9.272329418879768e-09
# [Parameter containing:
# tensor(0.6988, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(0.0149) tensor(-0.2392, dtype=torch.float64)
# Epoch 3/8 at cost=0.03414438414418087
# 1.4009557078154119e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(0.0367) tensor(0.0674, dtype=torch.float64)
# Epoch 3/8 at cost=0.027491105106373873
# 1.4507572821885594e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0151, dtype=torch.float64, requires_grad=True)]
# tensor(0.2559) tensor(2.6081, dtype=torch.float64)
# Epoch 3/8 at cost=0.031461388028179244
# 1.5144684358980712e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0151, dtype=torch.float64, requires_grad=True)]
# tensor(-0.3101) tensor(-2.2863, dtype=torch.float64)
# Epoch 3/8 at cost=0.06518840043950487
# 1.2415558234356834e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0150, dtype=torch.float64, requires_grad=True)]
# tensor(0.0616) tensor(0.1532, dtype=torch.float64)
# Epoch 3/8 at cost=0.020848373340317465
# 1.4537064426978809e-08
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0150, dtype=torch.float64, requires_grad=True)]
# tensor(2.7192) tensor(4.5341, dtype=torch.float64)
# Epoch 3/8 at cost=0.3898811717502511
# 9.130420345983923e-09
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0150, dtype=torch.float64, requires_grad=True)]
# tensor(-1.5800) tensor(-8.6110, dtype=torch.float64)
# Epoch 3/8 at cost=0.4911614633882194
# 8.078500858846362e-09
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(-0.4840) tensor(-2.9028, dtype=torch.float64)
# Epoch 4/8 at cost=0.03461142297268928
# 1.3647234319006405e-08
# [Parameter containing:
# tensor(0.6984, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(0.2702) tensor(0.8810, dtype=torch.float64)
# Epoch 4/8 at cost=0.027519897817457648
# 1.3287451909004065e-08
# [Parameter containing:
# tensor(0.6984, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(0.2623) tensor(1.3921, dtype=torch.float64)
# Epoch 4/8 at cost=0.03066163518593819
# 1.3716104684002139e-08
# [Parameter containing:
# tensor(0.6984, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(-0.4066) tensor(-2.6198, dtype=torch.float64)
# Epoch 4/8 at cost=0.06414787077460712
# 1.1243538749769733e-08
# [Parameter containing:
# tensor(0.6983, requires_grad=True), Parameter containing:
# tensor(0.0148, dtype=torch.float64, requires_grad=True)]
# tensor(0.0341) tensor(-0.0062, dtype=torch.float64)
# Epoch 4/8 at cost=0.020855591768828903
# 1.4195876087671906e-08
# [Parameter containing:
# tensor(0.6984, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(-18.3467) tensor(-106.6498, dtype=torch.float64)
# Epoch 4/8 at cost=0.413959405972262
# 8.817977847532133e-09
# [Parameter containing:
# tensor(0.6984, requires_grad=True), Parameter containing:
# tensor(0.0149, dtype=torch.float64, requires_grad=True)]
# tensor(0.5119) tensor(1.5030, dtype=torch.float64)
# Epoch 4/8 at cost=0.4915751008398999
# 8.01653976074422e-09
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0150, dtype=torch.float64, requires_grad=True)]
# tensor(-0.3474) tensor(-1.9876, dtype=torch.float64)
# Epoch 5/8 at cost=0.03473025835874776
# 1.3627884386863041e-08
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0150, dtype=torch.float64, requires_grad=True)]
# tensor(0.0916) tensor(0.2267, dtype=torch.float64)
# Epoch 5/8 at cost=0.02754875038998819
# 1.3617101659683013e-08
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0151, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0354) tensor(0.0252, dtype=torch.float64)
# Epoch 5/8 at cost=0.03147874607850812
# 1.457016296252045e-08
# [Parameter containing:
# tensor(0.6985, requires_grad=True), Parameter containing:
# tensor(0.0151, dtype=torch.float64, requires_grad=True)]
# tensor(0.9225) tensor(3.6864, dtype=torch.float64)
# Epoch 5/8 at cost=0.06509131489007206
# 1.2227745763574105e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0151, dtype=torch.float64, requires_grad=True)]
# tensor(0.0467) tensor(0.0502, dtype=torch.float64)
# Epoch 5/8 at cost=0.020841680853051315
# 1.4644094598940159e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(1.7624) tensor(3.9961, dtype=torch.float64)
# Epoch 5/8 at cost=0.39050897885671254
# 8.9940532645004e-09
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(-1.3075) tensor(-7.1416, dtype=torch.float64)
# Epoch 5/8 at cost=0.48998706873987924
# 8.69551155942297e-09
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0603) tensor(-0.7380, dtype=torch.float64)
# Epoch 6/8 at cost=0.03423925368504417
# 1.3718002280437422e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0152, dtype=torch.float64, requires_grad=True)]
# tensor(0.0824) tensor(0.2541, dtype=torch.float64)
# Epoch 6/8 at cost=0.027472168434744284
# 1.4324188412253664e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(0.5095) tensor(3.1960, dtype=torch.float64)
# Epoch 6/8 at cost=0.03153973561172754
# 1.531051036599491e-08
# [Parameter containing:
# tensor(0.6986, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(0.7654) tensor(2.4966, dtype=torch.float64)
# Epoch 6/8 at cost=0.06497346527549541
# 1.2778100460385423e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0811) tensor(-0.4221, dtype=torch.float64)
# Epoch 6/8 at cost=0.02079012048101752
# 1.4881776280658393e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(1.6748) tensor(5.1527, dtype=torch.float64)
# Epoch 6/8 at cost=0.3911786766985768
# 8.743734776254613e-09
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(-0.5743) tensor(-3.5734, dtype=torch.float64)
# Epoch 6/8 at cost=0.4893325350183101
# 8.963455786751407e-09
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0416) tensor(-0.7816, dtype=torch.float64)
# Epoch 7/8 at cost=0.03410250002569922
# 1.3792610188399534e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(0.0227) tensor(0.0811, dtype=torch.float64)
# Epoch 7/8 at cost=0.027493504442111107
# 1.4546153122558786e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(0.4265) tensor(3.4592, dtype=torch.float64)
# Epoch 7/8 at cost=0.03184992087180281
# 1.5569638163257395e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(-0.1777) tensor(-1.6111, dtype=torch.float64)
# Epoch 7/8 at cost=0.06496290336830983
# 1.2933900450003832e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0153, dtype=torch.float64, requires_grad=True)]
# tensor(0.0664) tensor(0.1020, dtype=torch.float64)
# Epoch 7/8 at cost=0.020773179603220546
# 1.4966189977245708e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0905) tensor(-4.8868, dtype=torch.float64)
# Epoch 7/8 at cost=0.39093127247965714
# 8.748065719611759e-09
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(-0.7891) tensor(-4.4373, dtype=torch.float64)
# Epoch 7/8 at cost=0.4890408586408863
# 9.037274639670154e-09
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(0.1421) tensor(0.4106, dtype=torch.float64)
# Epoch 8/8 at cost=0.034125730190262916
# 1.3875238329489082e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(-0.1863) tensor(-0.9242, dtype=torch.float64)
# Epoch 8/8 at cost=0.027427391912783945
# 1.466628147627897e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(0.4537) tensor(2.8192, dtype=torch.float64)
# Epoch 8/8 at cost=0.03203699204296021
# 1.578924586030377e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(0.1189) tensor(-0.3889, dtype=torch.float64)
# Epoch 8/8 at cost=0.06508367698375533
# 1.3183392370125587e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(-0.0768) tensor(-0.3443, dtype=torch.float64)
# Epoch 8/8 at cost=0.020766062938438024
# 1.5149073632455764e-08
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(0.3249) tensor(-3.1011, dtype=torch.float64)
# Epoch 8/8 at cost=0.3903899701195407
# 8.695455104800988e-09
# [Parameter containing:
# tensor(0.6987, requires_grad=True), Parameter containing:
# tensor(0.0154, dtype=torch.float64, requires_grad=True)]
# tensor(-0.4717) tensor(-2.6818, dtype=torch.float64)
# Epoch 8/8 at cost=0.48874045665093385
# Finished Training

# %% [markdown]
# ## on train data

# %%
out_bftrain, out_hat = get_net_outputs(net, LearnedAAP(max_iter, 243 * 320, 11), r, train)
# Out:
# 9.526961563913226e-09
# 9.121774825280563e-09
# 1.8903064822417436e-08
# 1.3946544023765132e-08
# 1.4947006001759665e-08
# 1.4724306994413735e-08
# 1.984932305158066e-08
# 1.5847951040961433e-08
# 1.3719901029998578e-08
# 1.3240517518942454e-08
# 2.2113440484776582e-08
# 1.515220431249326e-08
# 9.312456760411683e-09
# 8.668636729878382e-09

# %%
out_hat[0][0].shape
# Out:
# (77760, 11)

# %%
import pdb
import matplotlib.pyplot as plt
out_accaltproj = []
out_accaltproj_adv = []
for i, M_true in enumerate(train):
    #pdb.set_trace()
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    kwargs = {'r': r, 'tol': 1e-06, 'gamma': torch.tensor(0.7), 'max_iter': max_iter}
    # pdb.set_trace()
    adv_M, _ = BIM(AccAltProj, M_true, L0, S0, alpha=0.01, steps=12,eps=0.07, **kwargs)


    # adv_M, _, _ = carlini_wagner(AccAltProj, M_true, c=8.8*10**5, lr=0.01, steps=20, **kwargs)

    # Plotting adv_m
    # adv_M
    # pdb.set_trace()
    combined = np.concatenate((adv_M[:,0].detach().numpy(), M_true[:,0].detach().numpy()))
    adv_M_numpy = adv_M.detach().numpy()
    plt.imshow(M_true[:,0].reshape(320, 243).T, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    plt.show()
    plt.imshow(adv_M_numpy[:,0].reshape(320,243).T, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
    # pdb.set_trace()
    plt.show()
    print(np.min(M_true[:,0].detach().numpy()))
    print(np.max(M_true[:,0].detach().numpy()))

    # pdb.set_trace()

    loss_adv, l_adv, s_adv = AccAltProj(adv_M, r, 1e-06, torch.tensor(0.7), max_iter)


    # pdb.set_trace()
    print(f"Loss gt {loss[-1]}")
    print(f"Loss adversarial {loss_adv[-1]}")
    out_accaltproj.append((L0, S0, M_true))
    out_accaltproj_adv.append([l_adv.detach().numpy(), s_adv.detach().numpy(), adv_M])
# Out:
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.11/bdb.py", line 336, in set_trace
#     sys.settrace(self.trace_dispatch)
# > <ipython-input-15-06c66d0294fe>(11)AccAltProj()
#       9     pdb.set_trace()
#      10
# ---> 11     norm_of_M0 = torch.linalg.norm(M0)
#      12     ## Keep track of loss
#      13     loss = []
#
# ipdb> m
# 77760
# ipdb> n
# > <ipython-input-15-06c66d0294fe>(13)AccAltProj()
#      11     norm_of_M0 = torch.linalg.norm(M0)
#      12     ## Keep track of loss
# ---> 13     loss = []
#      14     ## Initialization
#      15     beta = 1/(2 * np.power(m * n, 1/4))
#
# ipdb> n
# > <ipython-input-15-06c66d0294fe>(15)AccAltProj()
#      13     loss = []
#      14     ## Initialization
# ---> 15     beta = 1/(2 * np.power(m * n, 1/4))
#      16     beta_init = 4 * beta
#      17     zeta = beta_init * torch.linalg.norm(M0, 2)
#
# ipdb> print(n)
# 11
# ipdb> q
# PYDEV DEBUGGER WARNING:
# sys.settrace() should not be used when the debugger is being used.
# This may cause the debugger to stop working correctly.
# If this is needed, please check:
# http://pydev.blogspot.com/2007/06/why-cant-pydev-debugger-work-with.html
# to see how to restore the debug tracing back correctly.
# Call Location:
#   File "/usr/lib/python3.11/bdb.py", line 361, in set_quit
#     sys.settrace(None)

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
def save_fig(fname,path):
    """
    The function saves the current figure to the specified file by using plt.savefig with the file path obtained by joining FIGURES_PATH and fname
    :param fname:  File name or path to save the figure.
    """
    plt.savefig(os.path.join(path, fname), bbox_inches='tight', format='pdf', transparent=True)

# %%
# face_idx = 1
import os
x1=170
x2=200
y1=130
y2=180
def show_image(axs,img,secImg,face_idx,inset_limits, zoom_lvl=2.5, zoom_loc=2, inset_loc1=3, inset_loc2=4):
  x1,x2,y1,y2 = inset_limits
  combined = np.concatenate((img[:,face_idx], secImg[:,face_idx]))

  axs.imshow(img[:,face_idx].reshape(320, 243).T, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
  axs.get_xaxis().set_visible(False)
  axs.get_yaxis().set_visible(False)

  # zoomed image location
  axins = zoomed_inset_axes(axs, zoom_lvl, loc=zoom_loc)
  axins.imshow(img[:,face_idx].reshape(320, 243).T, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
  for axis in ['top','bottom','left','right']:
      axins.spines[axis].set_color('r')
  axins.set_xlim(x1, x2)
  axins.set_ylim(y1, y2)
  plt.xticks(visible=False)
  plt.yticks(visible=False)
  axins.invert_yaxis()
  # lines
  mark_inset(axs, axins, loc1= inset_loc1, loc2=inset_loc2, fc="none", ec='r', clip_on=False)

locations = { # person: -2
    #              x1  x2  y1  y2
    "nose"      : (170,200,110,160),
    "mouth"     : (150,220,160,200),
    "right_eye" : (195,245,90,125)
}
# locations = { # person: -1
#     #              x1  x2  y1  y2
#     "nose"      : (160,190,110,160),
#     "mouth"     : (150,220,160,200),
#     "right_eye" : (195,245,110,135)
# }
# Input/Pertubed - M, adv_M
# image number = 4
# M,L,S
# M_adv,L_adv,S_Adv
# 2X3 subplotsA

# TAKE ONLY ONE SUBJECT, Choose the old guy
image_number = 4
face_index = -2
def plot_images(person_index_list = [-2],face_index_list=[4],attack_name="BIM"):
  for person_idx in person_index_list:
    for face_idx in face_index_list:
      (L0, S0, M_true) = out_accaltproj[person_idx]
      [l_adv, s_adv, adv_M]=out_accaltproj_adv[person_idx]
      fig, axs = plt.subplots(2, 3)
      plt.subplots_adjust(wspace=0.1, hspace=0.1)
      import pdb

      # # pdb.set_trace()
      if type(M_true)==torch.Tensor:
        M_true = M_true.detach().numpy()
      if type(adv_M)==torch.Tensor:
        adv_M = adv_M.detach().numpy()

      show_image(axs[0,0],M_true,adv_M,face_idx,locations["nose"], zoom_lvl=2.8, zoom_loc=2, inset_loc1=1, inset_loc2=2)
      show_image(axs[1,0],adv_M,M_true,face_idx,locations["nose"], zoom_lvl=2.8, zoom_loc=2, inset_loc1=1, inset_loc2=2)
      show_image(axs[0,1],L0,l_adv,face_idx,locations["mouth"], zoom_lvl=2, zoom_loc=2, inset_loc1=3, inset_loc2=4)
      show_image(axs[1,1],l_adv,L0,face_idx,locations["mouth"], zoom_lvl=2, zoom_loc=2, inset_loc1=3, inset_loc2=4)
      show_image(axs[0,2],S0,s_adv,face_idx,locations["right_eye"], zoom_lvl=2.8, zoom_loc=2, inset_loc1=3, inset_loc2=4)
      show_image(axs[1,2],s_adv,S0,face_idx,locations["right_eye"], zoom_lvl=2.8, zoom_loc=2, inset_loc1=3, inset_loc2=4)
      if not os.path.isdir("plots"):
        os.mkdir("plots")
      save_fig("attack_RPCA_Yale_"+attack_name+".pdf","plots//")

all_persons = list(range(len(out_accaltproj)))
all_faces   = list(range(len(out_accaltproj[0][0][0,:])))
# plot_images(person_index_list=[0],face_index_list=[-2],attack_name="CW")
# plot_images(person_index_list=[0],face_index_list=[1])

plot_images(person_index_list=[-3],face_index_list=[-3],attack_name="BIM")

# %%
import matplotlib.pyplot as plt

subject_num = 4

subject1_out_accaltproj = out_accaltproj[subject_num]
lowrank_out_accaltproj = subject1_out_accaltproj[0]
sparse_out_accaltproj = subject1_out_accaltproj[1]


subject1_out_accaltproj_adv = out_accaltproj_adv[subject_num]
lowrank_out_accaltproj_adv = subject1_out_accaltproj_adv[0]
sparse_out_accaltproj_adv = subject1_out_accaltproj_adv[1]

subject1_out_hat = out_hat[subject_num]
lowrank_out_hat = subject1_out_hat[0]
sparse_out_hat = subject1_out_hat[1]


subject1_train_est = train_est[subject_num]
lowrank_train_est = subject1_train_est[0]
sparse_train_est = subject1_train_est[1]

subject1_out_bftrain = out_bftrain[subject_num]
lowrank_out_bftrain = subject1_out_bftrain[0]
sparse_out_bftrain = subject1_out_bftrain[1]


for i in range(11):

    # remove lowrank_out_hat,  sparse_out_hat from here - and add the M_adv, M_ground-truth (do not plot all the 11 faces, only the first)
    plot_true_vs_est_matrices((lowrank_out_hat[:,i].reshape(320, 243).T) \
                            , (lowrank_out_accaltproj_adv[:,i].reshape(320, 243).T) \
                            , (lowrank_out_accaltproj[:,i].reshape(320, 243).T) \
                            , (sparse_out_hat[:,i].reshape(320, 243).T) \
                            , (sparse_out_accaltproj_adv[:,i].reshape(320, 243).T) \
                            , (sparse_out_accaltproj[:,i].reshape(320, 243).T))

# %% [markdown]
# ## on test data

# %%
print(list(net.parameters()))

# %%
out_accaltproj_ontest = []
out_ircur_ontest = []
for i, M_true in enumerate(test):
    loss, L0, S0 = AccAltProj(M_true, r, 1e-06, torch.tensor(0.7), max_iter)
    print(loss[-1])
    out_accaltproj_ontest.append((L0, S0, M_true))
    loss, L0, S0 = IRCUR(M_true, r, 1e-06, torch.tensor(0.7), 3, max_iter)
    out_ircur_ontest.append((L0, S0, M_true))

# %%
out_bftrain_ontest, out_hat_ontest = get_net_outputs(net, LearnedAAP(max_iter, 243 * 320, 11), r, test)

# %%
subject1_accaltproj_ontest = out_accaltproj_ontest[5]
subject1_ircur_ontest = out_ircur_ontest[5]
subject1_out_hat_ontest = out_hat_ontest[5]
subject1_out_bftrain_ontest = out_bftrain_ontest[5]
lowrank_accaltproj_ontest = subject1_accaltproj_ontest[0]
lowrank_ircur_ontest = subject1_ircur_ontest[0]
lowrank_out_hat_ontest = subject1_out_hat_ontest[0]
lowrank_out_bftrain_ontest = subject1_out_bftrain_ontest[0]
sparse_accaltproj_ontest = subject1_accaltproj_ontest[1]
sparse_ircur_ontest = subject1_ircur_ontest[1]
sparse_out_hat_ontest = subject1_out_hat_ontest[1]
sparse_out_bftrain_ontest = subject1_out_bftrain_ontest[1]
for i in range(11):
    plot_true_vs_est_matrices_original((lowrank_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
                            , (lowrank_ircur_ontest[:,i].reshape(320, 243).T * 255) \
                            , (sparse_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
                            , (sparse_ircur_ontest[:,i].reshape(320, 243).T * 255))

# %%
L_hat = (lowrank_out_hat_ontest[:,6].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,6].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,6].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,6].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,6].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,6].reshape(320, 243).T * 255)

combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))
plt.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')
plt.show()
# plt.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
# plt.savefig('plots/face_ircur_lr.eps', format='eps')
# plt.show()
plt.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')
plt.show()
plt.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')
plt.show()
# plt.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
# plt.savefig('plots/face_ircur_sad.eps', format='eps')
# plt.show()
plt.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')
plt.show()

# plot_true_vs_est_matrices((lowrank_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
#                         , (lowrank_ircur_ontest[:,i].reshape(320, 243).T * 255) \
#                         , (sparse_out_hat_ontest[:,i].reshape(320, 243).T * 255) \
#                         , (sparse_ircur_ontest[:,i].reshape(320, 243).T * 255))

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)

fig = plt.figure()
plt.imshow(L_hat-L_accaltproj.numpy(), cmap='gray')

fig = plt.figure()
plt.imshow(np.concatenate((L_hat, L_ircur, L_accaltproj), axis=1), cmap='gray')


fig = plt.figure()
plt.imshow(S_hat-S_accaltproj.numpy(), cmap='gray')

fig = plt.figure()
plt.imshow(np.concatenate((S_hat, S_ircur, S_accaltproj), axis=1), cmap='gray')

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)


combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=170
x2=200
y1=130
y2=180


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_sad.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)


combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=150
x2=180
y1=170
y2=200


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_sad.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)


combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=105
x2=130
y1=140
y2=180


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_unrolled_s_happy.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_ircur_s_happy.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_13_accaltproj_s_happy.eps', format='eps')

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)


combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=145
x2=215
y1=85
y2=100


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_sad.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')

# %%
subject1_accaltproj_ontest = out_accaltproj_ontest[2]
subject1_ircur_ontest = out_ircur_ontest[2]
subject1_out_hat_ontest = out_hat_ontest[2]
subject1_out_bftrain_ontest = out_bftrain_ontest[2]
lowrank_accaltproj_ontest = subject1_accaltproj_ontest[0]
lowrank_ircur_ontest = subject1_ircur_ontest[0]
lowrank_out_hat_ontest = subject1_out_hat_ontest[0]
lowrank_out_bftrain_ontest = subject1_out_bftrain_ontest[0]
sparse_accaltproj_ontest = subject1_accaltproj_ontest[1]
sparse_ircur_ontest = subject1_ircur_ontest[1]
sparse_out_hat_ontest = subject1_out_hat_ontest[1]
sparse_out_bftrain_ontest = subject1_out_bftrain_ontest[1]

# %%
L_hat = (lowrank_out_hat_ontest[:,2].reshape(320, 243).T * 255)
S_hat = (sparse_out_hat_ontest[:,2].reshape(320, 243).T * 255)
L_ircur = (lowrank_ircur_ontest[:,2].reshape(320, 243).T * 255)
S_ircur = (sparse_ircur_ontest[:,2].reshape(320, 243).T * 255)
L_accaltproj = (lowrank_accaltproj_ontest[:,2].reshape(320, 243).T * 255)
S_accaltproj = (sparse_accaltproj_ontest[:,2].reshape(320, 243).T * 255)

fig = plt.figure()
plt.imshow(L_hat-L_accaltproj.numpy(), cmap='gray')

fig = plt.figure()
plt.imshow(np.concatenate((L_hat, L_ircur, L_accaltproj), axis=1), cmap='gray')

# %%
combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=100
x2=140
y1=90
y2=120

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_unrolled_s_happy.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_ircur_s_happy.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
plt.xticks(visible=False)
plt.yticks(visible=False)
axins = zoomed_inset_axes(ax, 2.5, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/subject_10_accaltproj_s_happy.eps', format='eps')

# %%
combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=145#110
x2=200#160
y1=160#90
y2=195#140

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_sad.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')

# %%
combined = np.concatenate((L_hat, L_ircur, L_accaltproj, S_hat, S_ircur, S_accaltproj))

#where to zoom ?
x1=100
x2=140
y1=160
y2=210

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_lr.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 2, loc=2)
axins.imshow(L_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_lr.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_hat, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_unrolled_sad.eps', format='eps')


fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_ircur, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=4, fc="none", ec='r')
plt.savefig('plots/face_ircur_sad.eps', format='eps')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
axins = zoomed_inset_axes(ax, 3, loc=2)
axins.imshow(S_accaltproj, vmin=np.min(combined), vmax = np.max(combined), cmap='gray')
for axis in ['top','bottom','left','right']:
    axins.spines[axis].set_color('r')
axins.set_xlim(x1, x2)
axins.set_ylim(y1, y2)
plt.xticks(visible=False)
plt.yticks(visible=False)
axins.invert_yaxis()
mark_inset(ax, axins, loc1=3, loc2=2, fc="none", ec='r')
plt.savefig('plots/face_accaltproj_sad.eps', format='eps')
